# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/kaggle/input/iris/Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %% [markdown]
# **Checking is there any null values in DataFrame or not**

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# No null values present

# %%
#Describing the DataFrame

# %%
df.drop(labels=['Id'],axis=1,inplace=True)

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df['Species'].nunique()
# Out:
# 3

# %% [markdown]
# 3 means Species has 3 classes in it

# %%
#checking how many counts are in three classes of species
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# All three classes has 50 each counts

# %% [markdown]
# **Let's Find Minimum and maximum values of these classes for each columns**

# %%
df_setosa=df[df['Species']=='Iris-setosa']
df_versicolor=df[df['Species']=='Iris-versicolor']
df_virginica=df[df['Species']=='Iris-virginica']
# df_setosa.min()
# df_setosa.max()
print(df_versicolor.head())
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 50            7.0           3.2            4.7           1.4  Iris-versicolor
# 51            6.4           3.2            4.5           1.5  Iris-versicolor
# 52            6.9           3.1            4.9           1.5  Iris-versicolor
# 53            5.5           2.3            4.0           1.3  Iris-versicolor
# 54            6.5           2.8            4.6           1.5  Iris-versicolor

# %%
print(df_setosa['SepalLengthCm'].min())
print(df_setosa['SepalWidthCm'].min())
print(df_setosa['PetalLengthCm'].min())
print(df_setosa['PetalWidthCm'].min())
# Out:
# 4.3
# 2.3
# 1.0
# 0.1

# %%
print(df_setosa['SepalLengthCm'].max())
print(df_setosa['SepalWidthCm'].max())
print(df_setosa['PetalLengthCm'].max())
print(df_setosa['PetalWidthCm'].max())
# Out:
# 5.8
# 4.4
# 1.9
# 0.6

# %% [markdown]
# **Ploting Graphs using matplotlib and seaborn**

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#this is not very good for analyzing

plt.bar(df['Species'],df['SepalLengthCm'])
plt.show()

# %%
plt.scatter(df['Species'],df['SepalLengthCm'])
plt.xlabel('Species')
plt.ylabel('SepalLength(in cm)')
plt.show()

# %%
#expolatarion of above graph
print("min sepelLength of iris-setosa : " ,df_setosa['SepalLengthCm'].min())
print("min sepelLength of iris-vercicolor : " ,df_versicolor['SepalLengthCm'].min())
print("min sepelLength of iris-virginica : " ,df_virginica['SepalLengthCm'].min())
print("max sepelLength of iris-setosa : " ,df_setosa['SepalLengthCm'].max())
print("max sepelLength of iris-vercicolor : " ,df_versicolor['SepalLengthCm'].max())
print("max sepelLength of iris-virginica : " ,df_virginica['SepalLengthCm'].max())
# Out:
# min sepelLength of iris-setosa :  4.3
# min sepelLength of iris-vercicolor :  4.9
# min sepelLength of iris-virginica :  4.9
# max sepelLength of iris-setosa :  5.8
# max sepelLength of iris-vercicolor :  7.0
# max sepelLength of iris-virginica :  7.9

# %%
plt.scatter(df['Species'],df['SepalWidthCm'])
plt.xlabel('Species')
plt.ylabel('SepalWidth(in cm)')
plt.show()

# %%
#expolatarion of above graph
print("min sepelWidth of iris-setosa : " ,df_setosa['SepalWidthCm'].min())
print("min sepelWidth of iris-vercicolor : " ,df_versicolor['SepalWidthCm'].min())
print("min sepelWidth of iris-virginica : " ,df_virginica['SepalWidthCm'].min())
print("max sepelWidth of iris-setosa : " ,df_setosa['SepalWidthCm'].max())
print("max sepelWidth of iris-vercicolor : " ,df_versicolor['SepalWidthCm'].max())
print("max sepelWidth of iris-virginica : " ,df_virginica['SepalWidthCm'].max())
# Out:
# min sepelWidth of iris-setosa :  2.3
# min sepelWidth of iris-vercicolor :  2.0
# min sepelWidth of iris-virginica :  2.2
# max sepelWidth of iris-setosa :  4.4
# max sepelWidth of iris-vercicolor :  3.4
# max sepelWidth of iris-virginica :  3.8

# %%
plt.scatter(df['Species'],df['PetalLengthCm'])
plt.xlabel('Species')
plt.ylabel('PetalLength(in cm)')
plt.show()

# %%
#expolatarion of above graph
print("min PetalLengthCm of iris-setosa : " ,df_setosa['PetalLengthCm'].min())
print("min PetalLengthCm of iris-vercicolor : " ,df_versicolor['PetalLengthCm'].min())
print("min PetalLengthCm of iris-virginica : " ,df_virginica['PetalLengthCm'].min())
print("max PetalLengthCm of iris-setosa : " ,df_setosa['PetalLengthCm'].max())
print("max PetalLengthCm of iris-vercicolor : " ,df_versicolor['PetalLengthCm'].max())
print("max PetalLengthCm of iris-virginica : " ,df_virginica['PetalLengthCm'].max())
# Out:
# min PetalLengthCm of iris-setosa :  1.0
# min PetalLengthCm of iris-vercicolor :  3.0
# min PetalLengthCm of iris-virginica :  4.5
# max PetalLengthCm of iris-setosa :  1.9
# max PetalLengthCm of iris-vercicolor :  5.1
# max PetalLengthCm of iris-virginica :  6.9

# %%
plt.scatter(df['Species'],df['PetalWidthCm'])
plt.xlabel('Species')
plt.ylabel('PetalWidth(in cm)')
plt.show()

# %%
#expolatarion of above graph
print("min PetalWidthCm of iris-setosa : " ,df_setosa['PetalWidthCm'].min())
print("min PetalWidthCm of iris-vercicolor : " ,df_versicolor['PetalWidthCm'].min())
print("min PetalWidthCm of iris-virginica : " ,df_virginica['PetalWidthCm'].min())
print("max PetalWidthCm of iris-setosa : " ,df_setosa['PetalWidthCm'].max())
print("max PetalWidthCm of iris-vercicolor : " ,df_versicolor['PetalWidthCm'].max())
print("max PetalWidthCm of iris-virginica : " ,df_virginica['PetalWidthCm'].max())
# Out:
# min PetalWidthCm of iris-setosa :  0.1
# min PetalWidthCm of iris-vercicolor :  1.0
# min PetalWidthCm of iris-virginica :  1.4
# max PetalWidthCm of iris-setosa :  0.6
# max PetalWidthCm of iris-vercicolor :  1.8
# max PetalWidthCm of iris-virginica :  2.5

# %%
#Finding Which column is skewed

# %%
df_skew=pd.DataFrame(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']])
df_skew.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
skewness=df_skew.skew()
print(skewness)
# Out:
# SepalLengthCm    0.314911
# SepalWidthCm     0.334053
# PetalLengthCm   -0.274464
# PetalWidthCm    -0.104997
# dtype: float64

# %% [markdown]
# **Above Analysis says that**
#
# Coloumn SepalWidthCm is most RigthSkewwed Column
#
# Coloumn PetalLengthCm is most leftSkewwed Column

# %%
#Finding Outliers in Dataset
#plotting box graph for it

# %%
sns.boxplot(x='Species',y='SepalLengthCm',data=df)
plt.show()

# %%
df_setosa.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count       50.00000     50.000000      50.000000      50.00000
# mean         5.00600      3.418000       1.464000       0.24400
# std          0.35249      0.381024       0.173511       0.10721
# min          4.30000      2.300000       1.000000       0.10000
# 25%          4.80000      3.125000       1.400000       0.20000
# 50%          5.00000      3.400000       1.500000       0.20000
# 75%          5.20000      3.675000       1.575000       0.30000
# max          5.80000      4.400000       1.900000       0.60000

# %%
# df_setosa = df_setosa.reset_index(drop=True)
q25 = df_setosa['SepalLengthCm'].quantile(0.25)
q75=df_setosa['SepalLengthCm'].quantile(0.75)

iqr = q75 - q25

lower_bound = q25 - 1.5 * iqr
upper_bound = q75 + 1.5 * iqr

filtered_df = df_setosa[(df_setosa['SepalLengthCm'] < lower_bound) | (df_setosa['SepalLengthCm'] > upper_bound) ]
count=filtered_df['SepalLengthCm'].count()
print(count)

#it shows 0 columns
#it means it species setosa has 0 outliers in sepalLength
# Out:
# 0

# %%
# df_versicolor = df_versicolor.reset_index(drop=True)
q25 = df_versicolor['SepalLengthCm'].quantile(0.25)
q75=df_versicolor['SepalLengthCm'].quantile(0.75)

iqr = q75 - q25

lower_bound = q25 - 1.5 * iqr
upper_bound = q75 + 1.5 * iqr

filtered_df = df_versicolor[(df_versicolor['SepalLengthCm'] < lower_bound) | (df_versicolor['SepalLengthCm'] > upper_bound) ]
count=filtered_df['SepalLengthCm'].count()
print(count)

#it shows 0 columns
#it means it species setosa has 0 outliers in sepalLength
# Out:
# 0

# %%
# df_virginica = df_virginica.reset_index(drop=True)
q25 = df_virginica['SepalLengthCm'].quantile(0.25)
q75=df_virginica['SepalLengthCm'].quantile(0.75)

iqr = q75 - q25

lower_bound = q25 - 1.5 * iqr
upper_bound = q75 + 1.5 * iqr

filtered_df = df_virginica[(df_virginica['SepalLengthCm'] < lower_bound) | (df_virginica['SepalLengthCm'] > upper_bound) ]


count=filtered_df['SepalLengthCm'].count()
print(count)

#it shows 1 columns
#it means it species setosa has 1 outliers in sepalLength
# Out:
# 1

# %%
sns.boxplot(x='Species',y='SepalWidthCm',data=df)
plt.show()

# %%
#above box plot shows only iris virginica has an outlier

# %%
q25 = df_virginica['SepalWidthCm'].quantile(0.25)
q75=df_virginica['SepalWidthCm'].quantile(0.75)

iqr = q75 - q25

lower_bound = q25 - 1.5 * iqr
upper_bound = q75 + 1.5 * iqr

filtered_df = df_virginica[(df_virginica['SepalWidthCm'] < lower_bound) | (df_virginica['SepalWidthCm'] > upper_bound) ]
print(filtered_df)
print()
count=filtered_df['SepalWidthCm'].count()

print(count)

#it shows 3 columns
#it means it species setosa has 3 outliers in sepalLength
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 117            7.7           3.8            6.7           2.2  Iris-virginica
# 119            6.0           2.2            5.0           1.5  Iris-virginica
# 131            7.9           3.8            6.4           2.0  Iris-virginica
#
# 3

# %%
sns.boxplot(x='Species',y='PetalLengthCm',data=df)
plt.show()

# %%
#above graph shows that species setosa and versicolor has outliers in petelLength

# %%
q25 = df_setosa['PetalLengthCm'].quantile(0.25)
q75=df_setosa['PetalLengthCm'].quantile(0.75)

iqr = q75 - q25

lower_bound = q25 - 1.5 * iqr
upper_bound = q75 + 1.5 * iqr

filtered_df = df_setosa[(df_setosa['PetalLengthCm'] < lower_bound) | (df_setosa['PetalLengthCm'] > upper_bound) ]
print(filtered_df)
print()

count=filtered_df['PetalLengthCm'].count()
print(count)

#it shows 4 columns
#it means it species setosa has 4 outliers in sepalLength
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 13            4.3           3.0            1.1           0.1  Iris-setosa
# 22            4.6           3.6            1.0           0.2  Iris-setosa
# 24            4.8           3.4            1.9           0.2  Iris-setosa
# 44            5.1           3.8            1.9           0.4  Iris-setosa
#
# 4

# %%
q25 = df_versicolor['PetalLengthCm'].quantile(0.25)
q75=df_versicolor['PetalLengthCm'].quantile(0.75)

iqr = q75 - q25

lower_bound = q25 - 1.5 * iqr
upper_bound = q75 + 1.5 * iqr

filtered_df = df_versicolor[(df_versicolor['PetalLengthCm'] < lower_bound) | (df_versicolor['PetalLengthCm'] > upper_bound) ]
print(filtered_df['PetalLengthCm'])
print()

count=filtered_df['PetalLengthCm'].count()
print(count)

#it shows 1 columns
#it means it species setosa has 1 outliers in sepalLength
# Out:
# 98    3.0
# Name: PetalLengthCm, dtype: float64
#
# 1

# %%
sns.boxplot(x='Species',y='PetalWidthCm',data=df)
plt.show()

# %%
#above graph shows that only species setosa has outliers

# %%
q25 = df_setosa['PetalWidthCm'].quantile(0.25)
q75=df_setosa['PetalWidthCm'].quantile(0.75)

iqr = q75 - q25

lower_bound = q25 - 1.5 * iqr
upper_bound = q75 + 1.5 * iqr

filtered_df = df_setosa[(df_setosa['PetalWidthCm'] < lower_bound) | (df_setosa['PetalWidthCm'] > upper_bound) ]
print(filtered_df)
print()

count=filtered_df['PetalWidthCm'].count()
print(count)

#it shows 2 columns
#it means it species setosa has 2 outliers in sepalLength
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 23            5.1           3.3            1.7           0.5  Iris-setosa
# 43            5.0           3.5            1.6           0.6  Iris-setosa
#
# 2

# %%
#for finding which species depend on which column

# %%
sns.pairplot(data=df,
            kind='scatter',
            hue='Species')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# sns.heatmap(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm',
#               'PetalWidthCm']].corr() , annot=True)

# %%
sns.heatmap(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']].corr(),annot=True)
# Out:
# <Axes: >

# %%
#sns.heatmap(df.corr())

# %%
# df=df[(for(i in  df['Species']):
#     if df['Species']=='Iris-setosa':
#         return 1
#     elif df['Species']=='Iris-versicolor':
#         return 2
#     else:
#         return 3)].map()
# species_mapping = {'Iris-setosa':1 ,'Iris-versicolor':2,'Iris-virginica':3}
# df['Species'].map(species_mapping)


# sns.heatmap(df.corr(),annot =True)

# %%
# species_mapping = {'Iris-setosa': 1, 'Iris-versicolor': 2, 'Iris-virginica': 3}

# # Map the species to numeric values and create a new column
# df['Species_numeric'] = df['Species'].map(species_mapping)

# # If you need to filter the DataFrame based on certain conditions, do it here
# # Example: Filtering out a specific species
# # df = df[df['Species'] == 'Iris-setosa']

# # Generate the correlation matrix
# correlation_matrix = df.corr()

# # Plot the heatmap
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# plt.title('Correlation Matrix Heatmap')
# plt.show()

# %%
sns.histplot(df['SepalLengthCm'],kde=True)
plt.title("Histogram")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(df['PetalLengthCm'],kde=True)
plt.title("Histogram")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(df['SepalWidthCm'],kde=True)
plt.title("Histogram")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(df['PetalWidthCm'],kde=True)
plt.title("Histogram")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
skewness=df_skew.skew()
print(skewness)
# Out:
# SepalLengthCm    0.314911
# SepalWidthCm     0.334053
# PetalLengthCm   -0.274464
# PetalWidthCm    -0.104997
# dtype: float64
